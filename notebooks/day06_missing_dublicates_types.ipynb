# %%
import pandas as pd

df = pd.read_csv("../datasets/employees.csv")
df.head()
# Out:
#    Name  Age  Salary Department
# 0  Amit   24   35000         HR
# 1  Riya   26   42000         IT
# 2  John   22   30000      Sales
# 3  Sara   25   40000         IT

# %%
df.isnull()
# Out:
#     Name    Age  Salary  Department
# 0  False  False   False       False
# 1  False  False   False       False
# 2  False  False   False       False
# 3  False  False   False       False

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           0
# Salary        0
# Department    0
# dtype: int64

# %%
df.dropna()
# Out:
#    Name  Age  Salary Department
# 0  Amit   24   35000         HR
# 1  Riya   26   42000         IT
# 2  John   22   30000      Sales
# 3  Sara   25   40000         IT

# %%
df["Salary"].fillna(df["Salary"].mean())
# Out:
# 0    35000
# 1    42000
# 2    30000
# 3    40000
# Name: Salary, dtype: int64

# %%
df["Department"].fillna("Unknown")
# Out:
# 0       HR
# 1       IT
# 2    Sales
# 3       IT
# Name: Department, dtype: str

# %%
df["Salary"].fillna(df["Salary"].mean(), inplace=True)
# Out:
# C:\Users\Abhihail Jacob\AppData\Local\Temp\ipykernel_12080\2346652894.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Salary"].fillna(df["Salary"].mean(), inplace=True)
# 0    35000
# 1    42000
# 2    30000
# 3    40000
# Name: Salary, dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#    Name  Age  Salary Department
# 0  Amit   24   35000         HR
# 1  Riya   26   42000         IT
# 2  John   22   30000      Sales
# 3  Sara   25   40000         IT

# %%
df.dtypes
# Out:
# Name            str
# Age           int64
# Salary        int64
# Department      str
# dtype: object

# %%
df["Salary"] = df["Salary"].astype(float)

# %%
df.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12080\1543814071.py in ?()
# ----> 1 df.type
#
# d:\AI Journey\ai-journey\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
df.dtypes
# Out:
# Name              str
# Age             int64
# Salary        float64
# Department        str
# dtype: object

# %%
df["joining_date"] = pd.to_datetime(df["joining_date"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\AI Journey\ai-journey\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'joining_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df["joining_date"] = pd.to_datetime(df["joining_date"])
#
# File d:\AI Journey\ai-journey\venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File d:\AI Journey\ai-journey\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'joining_date'

# %%
df.columns.tolist()
# Out:
# ['Name', 'Age', 'Salary', 'Department']

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary', 'Department'], dtype='str')

# %%
df.dtypes
# Out:
# Name              str
# Age             int64
# Salary        float64
# Department        str
# dtype: object
